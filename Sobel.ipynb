# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import numpy as np
import cv2
import pandas as pd
from urllib import request
import json
import matplotlib.pyplot as plt
from skimage import io
from skimage.filters.rank import entropy
from skimage.morphology import disk
from skimage.filters import try_all_threshold, roberts, sobel, scharr, prewitt

# %%
img = io.imread("/content/drive/MyDrive/BTP/Results- Part-1/dataset/images/image9.png", as_gray = True)

# %%
# entr_img = entropy(img, disk(10))
# plt.imshow(entr_img)
ro = sobel(img, )
plt.imshow(ro, cmap='gray')

# %%
hist = np.histogram(np.ravel(ro), bins=256)
plt.plot(hist[1][:-1], hist[0])
plt.show()

# %%
thresh = cv2.threshold(ro, 0.05, 1, cv2.THRESH_BINARY)[1]
filtered_image = thresh

# %%
plt.imshow(thresh, cmap='gray')

# %%
fig, ax = try_all_threshold(ro, figsize = (10, 8), verbose = False)
plt.show();
